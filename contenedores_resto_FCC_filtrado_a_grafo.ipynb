# %% [markdown]
# ## Generamos el grafo

# %%
# Subimos el archivo de contenedores_resto_Valencia_filtrado


import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

import osmnx as ox
from shapely.geometry import LineString, Point
import networkx as nx
import folium

contenedores_resto = "Contenedores_resto_FCC_valencia_filtrado.csv"

contenedores_resto_filtrado_df= pd.read_csv(contenedores_resto, sep=',', engine='python')
print(f"Número de contenedores de resto: {contenedores_resto_filtrado_df.count()}")

display(contenedores_resto_filtrado_df.sample(5))
# Out:
# Número de contenedores de resto: calleempre           1797
# nº_contenedores      1797
# Lateral Derecha      1797
# Lateral Izquierda    1797
# Trasera              1797
# lat                  1797
# lon                  1797
# dtype: int64
#                           calleempre  nº_contenedores  Lateral Derecha  \
# 966             C/ JOSEP GROLLO, 105                2                2
# 1238  C/ PINTOR FERRER CALATAIUD, 13                2                2
# 210     AV MESTRE RODRIGO (MÚSIC), 6                1                1
# 1241   C/ PINTOR GENARO LAHUERTA, 23                2                2
# 1161          C/ PALMA DE GANDIA, 65                1                0
#
#       Lateral Izquierda  Trasera        lat       lon
# 966                   0        0  39.493362 -0.392365
# 1238                  0        0  39.467532 -0.337671
# 210                   0        0  39.477078 -0.397041
# 1241                  0        0  39.483014 -0.368557
# 1161                  0        1  39.528710 -0.384273

# %%
# Descargamos el grafo de calles para coches de Valencia


G = ox.graph_from_place("Valencia, Spain", network_type='drive', simplify=True)

G = ox.add_edge_speeds(G)        # km/h
G = ox.add_edge_travel_times(G)  # segundos

largest_cc = max(nx.strongly_connected_components(G), key=len)
G_sub = G.subgraph(largest_cc).copy()

# Definimos la función para insertar un contenedor en el grafo de la ciudad de Valencia
def insertar_contenedor_en_grafo(G, contenedor_id, lat, lon):
    from shapely.geometry import Point, LineString

    point = Point(lon, lat)
    u, v, key = ox.nearest_edges(G, lon, lat)
    data_uv = G.get_edge_data(u, v, key)

    # Geometría del edge original
    if 'geometry' in data_uv:
        edge_geom = data_uv['geometry']
    else:
        edge_geom = LineString([(G.nodes[u]['x'], G.nodes[u]['y']), (G.nodes[v]['x'], G.nodes[v]['y'])])

    # Proyectar el punto sobre la geometría
    nearest_point = edge_geom.interpolate(edge_geom.project(point))
    x_new, y_new = nearest_point.x, nearest_point.y

    # Crear nodo contenedor
    new_node = f"contenedor_{contenedor_id}"
    G.add_node(new_node, x=x_new, y=y_new, contenedor=True)

    # Crear geometrías para las nuevas aristas
    geom_uv = LineString([(G.nodes[u]['x'], G.nodes[u]['y']), (x_new, y_new)])
    geom_vu = LineString([(x_new, y_new), (G.nodes[v]['x'], G.nodes[v]['y'])])
    length_uv, length_vu = geom_uv.length, geom_vu.length

    # Atributos comunes
    attrs_base = data_uv.copy()
    for attr in ['geometry', 'length', 'travel_time']:
        attrs_base.pop(attr, None)

    speed = data_uv.get('speed_kph', 30)
    travel_time_uv = length_uv / (speed * 1000 / 3600)
    travel_time_vu = length_vu / (speed * 1000 / 3600)

    # Eliminar cualquier arista existente u→v o v→u
    if G.has_edge(u, v, key):
        G.remove_edge(u, v, key)
    if G.has_edge(v, u):
        for rev_key in list(G.get_edge_data(v, u).keys()):
            G.remove_edge(v, u, rev_key)

    # Añadir nuevas aristas obligando a pasar por el contenedor
    # u -> contenedor -> v
    G.add_edge(u, new_node, **dict(attrs_base, length=length_uv, travel_time=travel_time_uv, geometry=geom_uv))
    G.add_edge(new_node, v, **dict(attrs_base, length=length_vu, travel_time=travel_time_vu, geometry=geom_vu))

    # v -> contenedor -> u (simétrico)
    geom_vc = LineString([(G.nodes[v]['x'], G.nodes[v]['y']), (x_new, y_new)])
    geom_cu = LineString([(x_new, y_new), (G.nodes[u]['x'], G.nodes[u]['y'])])
    length_vc, length_cu = geom_vc.length, geom_cu.length
    travel_time_vc = length_vc / (speed * 1000 / 3600)
    travel_time_cu = length_cu / (speed * 1000 / 3600)

    G.add_edge(v, new_node, **dict(attrs_base, length=length_vc, travel_time=travel_time_vc, geometry=geom_vc))
    G.add_edge(new_node, u, **dict(attrs_base, length=length_cu, travel_time=travel_time_cu, geometry=geom_cu))

    return G

i = 0

for _, row in contenedores_resto_filtrado_df.iterrows():
    G_sub = insertar_contenedor_en_grafo(G_sub, row["calleempre"], row["lat"], row["lon"]) 
    i += 1
    print(f"Nodos interpolados: {i}")

gdf_edges = ox.graph_to_gdfs(G_sub, nodes=False, edges=True)
gdf_nodes = ox.graph_to_gdfs(G_sub, nodes=True, edges=False)

m = folium.Map(location=[39.4699, -0.3763], zoom_start=14)

for _, row in gdf_edges.iterrows():
    if row['geometry'].geom_type == 'LineString':
        coords = [(lat, lon) for lon, lat in row['geometry'].coords]
        folium.PolyLine(coords, color='black', weight=1, opacity=0.6).add_to(m)

contenedores = gdf_nodes[gdf_nodes['contenedor'] == True]
for _, row in contenedores.iterrows():
    folium.CircleMarker(
        location=[row['y'], row['x']],
        radius=6,
        color='blue',
        fill=True,
        fill_opacity=0.8,
        tooltip=f"Contenedor: {row.name}"
    ).add_to(m)

m.save("contenedores_resto_FCC_valencia_grafo.html")
print("Mapa guardado como mapa_grafo_contenedores.html")


ox.save_graphml(G_sub, filepath="contenedores_resto_FCC_valencia_filtrado_grafo.graphml")
# Out:
# Nodos interpolados: 1
# Nodos interpolados: 2
# Nodos interpolados: 3
# Nodos interpolados: 4
# Nodos interpolados: 5
# Nodos interpolados: 6
# Nodos interpolados: 7
# Nodos interpolados: 8
# Nodos interpolados: 9
# Nodos interpolados: 10
# Nodos interpolados: 11
# Nodos interpolados: 12
# Nodos interpolados: 13
# Nodos interpolados: 14
# Nodos interpolados: 15
# Nodos interpolados: 16
# Nodos interpolados: 17
# Nodos interpolados: 18
# Nodos interpolados: 19
# Nodos interpolados: 20
# Nodos interpolados: 21
# Nodos interpolados: 22
# Nodos interpolados: 23
# Nodos interpolados: 24
# Nodos interpolados: 25
# Nodos interpolados: 26
# Nodos interpolados: 27
# Nodos interpolados: 28
# Nodos interpolados: 29
# Nodos interpolados: 30
# Nodos interpolados: 31
# Nodos interpolados: 32
# Nodos interpolados: 33
# Nodos interpolados: 34
# Nodos interpolados: 35
# Nodos interpolados: 36
# Nodos interpolados: 37
# Nodos interpolados: 38
# Nodos interpolados: 39
# Nodos interpolados: 40
# Nodos interpolados: 41
# Nodos interpolados: 42
# Nodos interpolados: 43
# Nodos interpolados: 44
# Nodos interpolados: 45
# Nodos interpolados: 46
# Nodos interpolados: 47
# Nodos interpolados: 48
# Nodos interpolados: 49
# Nodos interpolados: 50
# Nodos interpolados: 51
# Nodos interpolados: 52
# Nodos interpolados: 53
# Nodos interpolados: 54
# Nodos interpolados: 55
# Nodos interpolados: 56
# Nodos interpolados: 57
# Nodos interpolados: 58
# Nodos interpolados: 59
# Nodos interpolados: 60
# Nodos interpolados: 61
# Nodos interpolados: 62
# Nodos interpolados: 63
# Nodos interpolados: 64
# Nodos interpolados: 65
# Nodos interpolados: 66
# Nodos interpolados: 67
# Nodos interpolados: 68
# Nodos interpolados: 69
# Nodos interpolados: 70
# Nodos interpolados: 71
# Nodos interpolados: 72
# Nodos interpolados: 73
# Nodos interpolados: 74
# Nodos interpolados: 75
# Nodos interpolados: 76
# Nodos interpolados: 77
# Nodos interpolados: 78
# Nodos interpolados: 79
# Nodos interpolados: 80
# Nodos interpolados: 81
# Nodos interpolados: 82
# Nodos interpolados: 83
# Nodos interpolados: 84
# Nodos interpolados: 85
# Nodos interpolados: 86
# Nodos interpolados: 87
# Nodos interpolados: 88
# Nodos interpolados: 89
# Nodos interpolados: 90
# Nodos interpolados: 91
# Nodos interpolados: 92
# Nodos interpolados: 93
# Nodos interpolados: 94
# Nodos interpolados: 95
# Nodos interpolados: 96
# Nodos interpolados: 97
# Nodos interpolados: 98
# Nodos interpolados: 99
# Nodos interpolados: 100
# Nodos interpolados: 101
# Nodos interpolados: 102
# Nodos interpolados: 103
# Nodos interpolados: 104
# Nodos interpolados: 105
# Nodos interpolados: 106
# Nodos interpolados: 107
# Nodos interpolados: 108
# Nodos interpolados: 109
# Nodos interpolados: 110
# Nodos interpolados: 111
# Nodos interpolados: 112
# Nodos interpolados: 113
# Nodos interpolados: 114
# Nodos interpolados: 115
# Nodos interpolados: 116
# Nodos interpolados: 117
# Nodos interpolados: 118
# Nodos interpolados: 119
# Nodos interpolados: 120
# Nodos interpolados: 121
# Nodos interpolados: 122
# Nodos interpolados: 123
# Nodos interpolados: 124
# Nodos interpolados: 125
# Nodos interpolados: 126
# Nodos interpolados: 127
# Nodos interpolados: 128
# Nodos interpolados: 129
# Nodos interpolados: 130
# Nodos interpolados: 131
# Nodos interpolados: 132
# Nodos interpolados: 133
# Nodos interpolados: 134
# Nodos interpolados: 135
# Nodos interpolados: 136
# Nodos interpolados: 137
# Nodos interpolados: 138
# Nodos interpolados: 139
# Nodos interpolados: 140
# Nodos interpolados: 141
# Nodos interpolados: 142
# Nodos interpolados: 143
# Nodos interpolados: 144
# Nodos interpolados: 145
# Nodos interpolados: 146
# Nodos interpolados: 147
# Nodos interpolados: 148
# Nodos interpolados: 149
# Nodos interpolados: 150
# Nodos interpolados: 151
# Nodos interpolados: 152
# Nodos interpolados: 153
# Nodos interpolados: 154
# Nodos interpolados: 155
# Nodos interpolados: 156
# Nodos interpolados: 157
# Nodos interpolados: 158
# Nodos interpolados: 159
# Nodos interpolados: 160
# Nodos interpolados: 161
# Nodos interpolados: 162
# Nodos interpolados: 163
# Nodos interpolados: 164
# Nodos interpolados: 165
# Nodos interpolados: 166
# Nodos interpolados: 167
# Nodos interpolados: 168
# Nodos interpolados: 169
# Nodos interpolados: 170
# Nodos interpolados: 171
# Nodos interpolados: 172
# Nodos interpolados: 173
# Nodos interpolados: 174
# Nodos interpolados: 175
# Nodos interpolados: 176
# Nodos interpolados: 177
# Nodos interpolados: 178
# Nodos interpolados: 179
# Nodos interpolados: 180
# Nodos interpolados: 181
# Nodos interpolados: 182
# Nodos interpolados: 183
# Nodos interpolados: 184
# Nodos interpolados: 185
# Nodos interpolados: 186
# Nodos interpolados: 187
# Nodos interpolados: 188
# Nodos interpolados: 189
# Nodos interpolados: 190
# Nodos interpolados: 191
# Nodos interpolados: 192
# Nodos interpolados: 193
# Nodos interpolados: 194
# Nodos interpolados: 195
# Nodos interpolados: 196
# Nodos interpolados: 197
# Nodos interpolados: 198
# Nodos interpolados: 199
# Nodos interpolados: 200
# Nodos interpolados: 201
# Nodos interpolados: 202
# Nodos interpolados: 203
# Nodos interpolados: 204
# Nodos interpolados: 205
# Nodos interpolados: 206
# Nodos interpolados: 207
# Nodos interpolados: 208
# Nodos interpolados: 209
# Nodos interpolados: 210
# Nodos interpolados: 211
# Nodos interpolados: 212
# Nodos interpolados: 213
# Nodos interpolados: 214
# Nodos interpolados: 215
# Nodos interpolados: 216
# Nodos interpolados: 217
# Nodos interpolados: 218
# Nodos interpolados: 219
# Nodos interpolados: 220
# Nodos interpolados: 221
# Nodos interpolados: 222
# Nodos interpolados: 223
# Nodos interpolados: 224
# Nodos interpolados: 225
# Nodos interpolados: 226
# Nodos interpolados: 227
# Nodos interpolados: 228
# Nodos interpolados: 229
# Nodos interpolados: 230
# Nodos interpolados: 231
# Nodos interpolados: 232
# Nodos interpolados: 233
# Nodos interpolados: 234
# Nodos interpolados: 235
# Nodos interpolados: 236
# Nodos interpolados: 237
# Nodos interpolados: 238
# Nodos interpolados: 239
# Nodos interpolados: 240
# Nodos interpolados: 241
# Nodos interpolados: 242
# Nodos interpolados: 243
# Nodos interpolados: 244
# Nodos interpolados: 245
# Nodos interpolados: 246
# Nodos interpolados: 247
# Nodos interpolados: 248
# Nodos interpolados: 249
# Nodos interpolados: 250
# Nodos interpolados: 251
# Nodos interpolados: 252
# Nodos interpolados: 253
# Nodos interpolados: 254
# Nodos interpolados: 255
# Nodos interpolados: 256
# Nodos interpolados: 257
# Nodos interpolados: 258
# Nodos interpolados: 259
# Nodos interpolados: 260
# Nodos interpolados: 261
# Nodos interpolados: 262
# Nodos interpolados: 263
# Nodos interpolados: 264
# Nodos interpolados: 265
# Nodos interpolados: 266
# Nodos interpolados: 267
# Nodos interpolados: 268
# Nodos interpolados: 269
# Nodos interpolados: 270
# Nodos interpolados: 271
# Nodos interpolados: 272
# Nodos interpolados: 273
# Nodos interpolados: 274
# Nodos interpolados: 275
# Nodos interpolados: 276
# Nodos interpolados: 277
# Nodos interpolados: 278
# Nodos interpolados: 279
# Nodos interpolados: 280
# Nodos interpolados: 281
# Nodos interpolados: 282
# Nodos interpolados: 283
# Nodos interpolados: 284
# Nodos interpolados: 285
# Nodos interpolados: 286
# Nodos interpolados: 287
# Nodos interpolados: 288
# Nodos interpolados: 289
# Nodos interpolados: 290
# Nodos interpolados: 291
# Nodos interpolados: 292
# Nodos interpolados: 293
# Nodos interpolados: 294
# Nodos interpolados: 295
# Nodos interpolados: 296
# Nodos interpolados: 297
# Nodos interpolados: 298
# Nodos interpolados: 299
# Nodos interpolados: 300
# Nodos interpolados: 301
# Nodos interpolados: 302
# Nodos interpolados: 303
# Nodos interpolados: 304
# Nodos interpolados: 305
# Nodos interpolados: 306
# Nodos interpolados: 307
# Nodos interpolados: 308
# Nodos interpolados: 309
# Nodos interpolados: 310
# Nodos interpolados: 311
# Nodos interpolados: 312
# Nodos interpolados: 313
# Nodos interpolados: 314
# Nodos interpolados: 315
# Nodos interpolados: 316
# Nodos interpolados: 317
# Nodos interpolados: 318
# Nodos interpolados: 319
# Nodos interpolados: 320
# Nodos interpolados: 321
# Nodos interpolados: 322
# Nodos interpolados: 323
# Nodos interpolados: 324
# Nodos interpolados: 325
# Nodos interpolados: 326
# Nodos interpolados: 327
# Nodos interpolados: 328
# Nodos interpolados: 329
# Nodos interpolados: 330
# Nodos interpolados: 331
# Nodos interpolados: 332
# Nodos interpolados: 333
# Nodos interpolados: 334
# Nodos interpolados: 335
# Nodos interpolados: 336
# Nodos interpolados: 337
# Nodos interpolados: 338
# Nodos interpolados: 339
# Nodos interpolados: 340
# Nodos interpolados: 341
# Nodos interpolados: 342
# Nodos interpolados: 343
# Nodos interpolados: 344
# Nodos interpolados: 345
# Nodos interpolados: 346
# Nodos interpolados: 347
# Nodos interpolados: 348
# Nodos interpolados: 349
# Nodos interpolados: 350
# Nodos interpolados: 351
# Nodos interpolados: 352
# Nodos interpolados: 353
# Nodos interpolados: 354
# Nodos interpolados: 355
# Nodos interpolados: 356
# Nodos interpolados: 357
# Nodos interpolados: 358
# Nodos interpolados: 359
# Nodos interpolados: 360
# Nodos interpolados: 361
# Nodos interpolados: 362
# Nodos interpolados: 363
# Nodos interpolados: 364
# Nodos interpolados: 365
# Nodos interpolados: 366
# Nodos interpolados: 367
# Nodos interpolados: 368
# Nodos interpolados: 369
# Nodos interpolados: 370
# Nodos interpolados: 371
# Nodos interpolados: 372
# Nodos interpolados: 373
# Nodos interpolados: 374
# Nodos interpolados: 375
# Nodos interpolados: 376
# Nodos interpolados: 377
# Nodos interpolados: 378
# Nodos interpolados: 379
# Nodos interpolados: 380
# Nodos interpolados: 381
# Nodos interpolados: 382
# Nodos interpolados: 383
# Nodos interpolados: 384
# Nodos interpolados: 385
# Nodos interpolados: 386
# Nodos interpolados: 387
# Nodos interpolados: 388
# Nodos interpolados: 389
# Nodos interpolados: 390
# Nodos interpolados: 391
# Nodos interpolados: 392
# Nodos interpolados: 393
# Nodos interpolados: 394
# Nodos interpolados: 395
# Nodos interpolados: 396
# Nodos interpolados: 397
# Nodos interpolados: 398
# Nodos interpolados: 399
# Nodos interpolados: 400
# Nodos interpolados: 401
# Nodos interpolados: 402
# Nodos interpolados: 403
# Nodos interpolados: 404
# Nodos interpolados: 405
# Nodos interpolados: 406
# Nodos interpolados: 407
# Nodos interpolados: 408
# Nodos interpolados: 409
# Nodos interpolados: 410
# Nodos interpolados: 411
# Nodos interpolados: 412
# Nodos interpolados: 413
# Nodos interpolados: 414
# Nodos interpolados: 415
# Nodos interpolados: 416
# Nodos interpolados: 417
# Nodos interpolados: 418
# Nodos interpolados: 419
# Nodos interpolados: 420
# Nodos interpolados: 421
# Nodos interpolados: 422
# Nodos interpolados: 423
# Nodos interpolados: 424
# Nodos interpolados: 425
# Nodos interpolados: 426
# Nodos interpolados: 427
# Nodos interpolados: 428
# Nodos interpolados: 429
# Nodos interpolados: 430
# Nodos interpolados: 431
# Nodos interpolados: 432
# Nodos interpolados: 433
# Nodos interpolados: 434
# Nodos interpolados: 435
# Nodos interpolados: 436
# Nodos interpolados: 437
# Nodos interpolados: 438
# Nodos interpolados: 439
# Nodos interpolados: 440
# Nodos interpolados: 441
# Nodos interpolados: 442
# Nodos interpolados: 443
# Nodos interpolados: 444
# Nodos interpolados: 445
# Nodos interpolados: 446
# Nodos interpolados: 447
# Nodos interpolados: 448
# Nodos interpolados: 449
# Nodos interpolados: 450
# Nodos interpolados: 451
# Nodos interpolados: 452
# Nodos interpolados: 453
# Nodos interpolados: 454
# Nodos interpolados: 455
# Nodos interpolados: 456
# Nodos interpolados: 457
# Nodos interpolados: 458
# Nodos interpolados: 459
# Nodos interpolados: 460
# Nodos interpolados: 461
# Nodos interpolados: 462
# Nodos interpolados: 463
# Nodos interpolados: 464
# Nodos interpolados: 465
# Nodos interpolados: 466
# Nodos interpolados: 467
# Nodos interpolados: 468
# Nodos interpolados: 469
# Nodos interpolados: 470
# Nodos interpolados: 471
# Nodos interpolados: 472
# Nodos interpolados: 473
# Nodos interpolados: 474
# Nodos interpolados: 475
# Nodos interpolados: 476
# Nodos interpolados: 477
# Nodos interpolados: 478
# Nodos interpolados: 479
# Nodos interpolados: 480
# Nodos interpolados: 481
# Nodos interpolados: 482
# Nodos interpolados: 483
# Nodos interpolados: 484
# Nodos interpolados: 485
# Nodos interpolados: 486
# Nodos interpolados: 487
# Nodos interpolados: 488
# Nodos interpolados: 489
# Nodos interpolados: 490
# Nodos interpolados: 491
# Nodos interpolados: 492
# Nodos interpolados: 493
# Nodos interpolados: 494
# Nodos interpolados: 495
# Nodos interpolados: 496
# Nodos interpolados: 497
# Nodos interpolados: 498
# Nodos interpolados: 499
# Nodos interpolados: 500
# Nodos interpolados: 501
# Nodos interpolados: 502
# Nodos interpolados: 503
# Nodos interpolados: 504
# Nodos interpolados: 505
# Nodos interpolados: 506
# Nodos interpolados: 507
# Nodos interpolados: 508
# Nodos interpolados: 509
# Nodos interpolados: 510
# Nodos interpolados: 511
# Nodos interpolados: 512
# Nodos interpolados: 513
# Nodos interpolados: 514
# Nodos interpolados: 515
# Nodos interpolados: 516
# Nodos interpolados: 517
# Nodos interpolados: 518
# Nodos interpolados: 519
# Nodos interpolados: 520
# Nodos interpolados: 521
# Nodos interpolados: 522
# Nodos interpolados: 523
# Nodos interpolados: 524
# Nodos interpolados: 525
# Nodos interpolados: 526
# Nodos interpolados: 527
# Nodos interpolados: 528
# Nodos interpolados: 529
# Nodos interpolados: 530
# Nodos interpolados: 531
# Nodos interpolados: 532
# Nodos interpolados: 533
# Nodos interpolados: 534
# Nodos interpolados: 535
# Nodos interpolados: 536
# Nodos interpolados: 537
# Nodos interpolados: 538
# Nodos interpolados: 539
# Nodos interpolados: 540
# Nodos interpolados: 541
# Nodos interpolados: 542
# Nodos interpolados: 543
# Nodos interpolados: 544
# Nodos interpolados: 545
# Nodos interpolados: 546
# Nodos interpolados: 547
# Nodos interpolados: 548
# Nodos interpolados: 549
# Nodos interpolados: 550
# Nodos interpolados: 551
# Nodos interpolados: 552
# Nodos interpolados: 553
# Nodos interpolados: 554
# Nodos interpolados: 555
# Nodos interpolados: 556
# Nodos interpolados: 557
# Nodos interpolados: 558
# Nodos interpolados: 559
# Nodos interpolados: 560
# Nodos interpolados: 561
# Nodos interpolados: 562
# Nodos interpolados: 563
# Nodos interpolados: 564
# Nodos interpolados: 565
# Nodos interpolados: 566
# Nodos interpolados: 567
# Nodos interpolados: 568
# Nodos interpolados: 569
# Nodos interpolados: 570
# Nodos interpolados: 571
# Nodos interpolados: 572
# Nodos interpolados: 573
# Nodos interpolados: 574
# Nodos interpolados: 575
# Nodos interpolados: 576
# Nodos interpolados: 577
# Nodos interpolados: 578
# Nodos interpolados: 579
# Nodos interpolados: 580
# Nodos interpolados: 581
# Nodos interpolados: 582
# Nodos interpolados: 583
# Nodos interpolados: 584
# Nodos interpolados: 585
# Nodos interpolados: 586
# Nodos interpolados: 587
# Nodos interpolados: 588
# Nodos interpolados: 589
# Nodos interpolados: 590
# Nodos interpolados: 591
# Nodos interpolados: 592
# Nodos interpolados: 593
# Nodos interpolados: 594
# Nodos interpolados: 595
# Nodos interpolados: 596
# Nodos interpolados: 597
# Nodos interpolados: 598
# Nodos interpolados: 599
# Nodos interpolados: 600
# Nodos interpolados: 601
# Nodos interpolados: 602
# Nodos interpolados: 603
# Nodos interpolados: 604
# Nodos interpolados: 605
# Nodos interpolados: 606
# Nodos interpolados: 607
# Nodos interpolados: 608
# Nodos interpolados: 609
# Nodos interpolados: 610
# Nodos interpolados: 611
# Nodos interpolados: 612
# Nodos interpolados: 613
# Nodos interpolados: 614
# Nodos interpolados: 615
# Nodos interpolados: 616
# Nodos interpolados: 617
# Nodos interpolados: 618
# Nodos interpolados: 619
# Nodos interpolados: 620
# Nodos interpolados: 621
# Nodos interpolados: 622
# Nodos interpolados: 623
# Nodos interpolados: 624
# Nodos interpolados: 625
# Nodos interpolados: 626
# Nodos interpolados: 627
# Nodos interpolados: 628
# Nodos interpolados: 629
# Nodos interpolados: 630
# Nodos interpolados: 631
# Nodos interpolados: 632
# Nodos interpolados: 633
# Nodos interpolados: 634
# Nodos interpolados: 635
# Nodos interpolados: 636
# Nodos interpolados: 637
# Nodos interpolados: 638
# Nodos interpolados: 639
# Nodos interpolados: 640
# Nodos interpolados: 641
# Nodos interpolados: 642
# Nodos interpolados: 643
# Nodos interpolados: 644
# Nodos interpolados: 645
# Nodos interpolados: 646
# Nodos interpolados: 647
# Nodos interpolados: 648
# Nodos interpolados: 649
# Nodos interpolados: 650
# Nodos interpolados: 651
# Nodos interpolados: 652
# Nodos interpolados: 653
# Nodos interpolados: 654
# Nodos interpolados: 655
# Nodos interpolados: 656
# Nodos interpolados: 657
# Nodos interpolados: 658
# Nodos interpolados: 659
# Nodos interpolados: 660
# Nodos interpolados: 661
# Nodos interpolados: 662
# Nodos interpolados: 663
# Nodos interpolados: 664
# Nodos interpolados: 665
# Nodos interpolados: 666
# Nodos interpolados: 667
# Nodos interpolados: 668
# Nodos interpolados: 669
# Nodos interpolados: 670
# Nodos interpolados: 671
# Nodos interpolados: 672
# Nodos interpolados: 673
# Nodos interpolados: 674
# Nodos interpolados: 675
# Nodos interpolados: 676
# Nodos interpolados: 677
# Nodos interpolados: 678
# Nodos interpolados: 679
# Nodos interpolados: 680
# Nodos interpolados: 681
# Nodos interpolados: 682
# Nodos interpolados: 683
# Nodos interpolados: 684
# Nodos interpolados: 685
# Nodos interpolados: 686
# Nodos interpolados: 687
# Nodos interpolados: 688
# Nodos interpolados: 689
# Nodos interpolados: 690
# Nodos interpolados: 691
# Nodos interpolados: 692
# Nodos interpolados: 693
# Nodos interpolados: 694
# Nodos interpolados: 695
# Nodos interpolados: 696
# Nodos interpolados: 697
# Nodos interpolados: 698
# Nodos interpolados: 699
# Nodos interpolados: 700
# Nodos interpolados: 701
# Nodos interpolados: 702
# Nodos interpolados: 703
# Nodos interpolados: 704
# Nodos interpolados: 705
# Nodos interpolados: 706
# Nodos interpolados: 707
# Nodos interpolados: 708
# Nodos interpolados: 709
# Nodos interpolados: 710
# Nodos interpolados: 711
# Nodos interpolados: 712
# Nodos interpolados: 713
# Nodos interpolados: 714
# Nodos interpolados: 715
# Nodos interpolados: 716
# Nodos interpolados: 717
# Nodos interpolados: 718
# Nodos interpolados: 719
# Nodos interpolados: 720
# Nodos interpolados: 721
# Nodos interpolados: 722
# Nodos interpolados: 723
# Nodos interpolados: 724
# Nodos interpolados: 725
# Nodos interpolados: 726
# Nodos interpolados: 727
# Nodos interpolados: 728
# Nodos interpolados: 729
# Nodos interpolados: 730
# Nodos interpolados: 731
# Nodos interpolados: 732
# Nodos interpolados: 733
# Nodos interpolados: 734
# Nodos interpolados: 735
# Nodos interpolados: 736
# Nodos interpolados: 737
# Nodos interpolados: 738
# Nodos interpolados: 739
# Nodos interpolados: 740
# Nodos interpolados: 741
# Nodos interpolados: 742
# Nodos interpolados: 743
# Nodos interpolados: 744
# Nodos interpolados: 745
# Nodos interpolados: 746
# Nodos interpolados: 747
# Nodos interpolados: 748
# Nodos interpolados: 749
# Nodos interpolados: 750
# Nodos interpolados: 751
# Nodos interpolados: 752
# Nodos interpolados: 753
# Nodos interpolados: 754
# Nodos interpolados: 755
# Nodos interpolados: 756
# Nodos interpolados: 757
# Nodos interpolados: 758
# Nodos interpolados: 759
# Nodos interpolados: 760
# Nodos interpolados: 761
# Nodos interpolados: 762
# Nodos interpolados: 763
# Nodos interpolados: 764
# Nodos interpolados: 765
# Nodos interpolados: 766
# Nodos interpolados: 767
# Nodos interpolados: 768
# Nodos interpolados: 769
# Nodos interpolados: 770
# Nodos interpolados: 771
# Nodos interpolados: 772
# Nodos interpolados: 773
# Nodos interpolados: 774
# Nodos interpolados: 775
# Nodos interpolados: 776
# Nodos interpolados: 777
# Nodos interpolados: 778
# Nodos interpolados: 779
# Nodos interpolados: 780
# Nodos interpolados: 781
# Nodos interpolados: 782
# Nodos interpolados: 783
# Nodos interpolados: 784
# Nodos interpolados: 785
# Nodos interpolados: 786
# Nodos interpolados: 787
# Nodos interpolados: 788
# Nodos interpolados: 789
# Nodos interpolados: 790
# Nodos interpolados: 791
# Nodos interpolados: 792
# Nodos interpolados: 793
# Nodos interpolados: 794
# Nodos interpolados: 795
# Nodos interpolados: 796
# Nodos interpolados: 797
# Nodos interpolados: 798
# Nodos interpolados: 799
# Nodos interpolados: 800
# Nodos interpolados: 801
# Nodos interpolados: 802
# Nodos interpolados: 803
# Nodos interpolados: 804
# Nodos interpolados: 805
# Nodos interpolados: 806
# Nodos interpolados: 807
# Nodos interpolados: 808
# Nodos interpolados: 809
# Nodos interpolados: 810
# Nodos interpolados: 811
# Nodos interpolados: 812
# Nodos interpolados: 813
# Nodos interpolados: 814
# Nodos interpolados: 815
# Nodos interpolados: 816
# Nodos interpolados: 817
# Nodos interpolados: 818
# Nodos interpolados: 819
# Nodos interpolados: 820
# Nodos interpolados: 821
# Nodos interpolados: 822
# Nodos interpolados: 823
# Nodos interpolados: 824
# Nodos interpolados: 825
# Nodos interpolados: 826
# Nodos interpolados: 827
# Nodos interpolados: 828
# Nodos interpolados: 829
# Nodos interpolados: 830
# Nodos interpolados: 831
# Nodos interpolados: 832
# Nodos interpolados: 833
# Nodos interpolados: 834
# Nodos interpolados: 835
# Nodos interpolados: 836
# Nodos interpolados: 837
# Nodos interpolados: 838
# Nodos interpolados: 839
# Nodos interpolados: 840
# Nodos interpolados: 841
# Nodos interpolados: 842
# Nodos interpolados: 843
# Nodos interpolados: 844
# Nodos interpolados: 845
# Nodos interpolados: 846
# Nodos interpolados: 847
# Nodos interpolados: 848
# Nodos interpolados: 849
# Nodos interpolados: 850
# Nodos interpolados: 851
# Nodos interpolados: 852
# Nodos interpolados: 853
# Nodos interpolados: 854
# Nodos interpolados: 855
# Nodos interpolados: 856
# Nodos interpolados: 857
# Nodos interpolados: 858
# Nodos interpolados: 859
# Nodos interpolados: 860
# Nodos interpolados: 861
# Nodos interpolados: 862
# Nodos interpolados: 863
# Nodos interpolados: 864
# Nodos interpolados: 865
# Nodos interpolados: 866
# Nodos interpolados: 867
# Nodos interpolados: 868
# Nodos interpolados: 869
# Nodos interpolados: 870
# Nodos interpolados: 871
# Nodos interpolados: 872
# Nodos interpolados: 873
# Nodos interpolados: 874
# Nodos interpolados: 875
# Nodos interpolados: 876
# Nodos interpolados: 877
# Nodos interpolados: 878
# Nodos interpolados: 879
# Nodos interpolados: 880
# Nodos interpolados: 881
# Nodos interpolados: 882
# Nodos interpolados: 883
# Nodos interpolados: 884
# Nodos interpolados: 885
# Nodos interpolados: 886
# Nodos interpolados: 887
# Nodos interpolados: 888
# Nodos interpolados: 889
# Nodos interpolados: 890
# Nodos interpolados: 891
# Nodos interpolados: 892
# Nodos interpolados: 893
# Nodos interpolados: 894
# Nodos interpolados: 895
# Nodos interpolados: 896
# Nodos interpolados: 897
# Nodos interpolados: 898
# Nodos interpolados: 899
# Nodos interpolados: 900
# Nodos interpolados: 901
# Nodos interpolados: 902
# Nodos interpolados: 903
# Nodos interpolados: 904
# Nodos interpolados: 905
# Nodos interpolados: 906
# Nodos interpolados: 907
# Nodos interpolados: 908
# Nodos interpolados: 909
# Nodos interpolados: 910
# Nodos interpolados: 911
# Nodos interpolados: 912
# Nodos interpolados: 913
# Nodos interpolados: 914
# Nodos interpolados: 915
# Nodos interpolados: 916
# Nodos interpolados: 917
# Nodos interpolados: 918
# Nodos interpolados: 919
# Nodos interpolados: 920
# Nodos interpolados: 921
# Nodos interpolados: 922
# Nodos interpolados: 923
# Nodos interpolados: 924
# Nodos interpolados: 925
# Nodos interpolados: 926
# Nodos interpolados: 927
# Nodos interpolados: 928
# Nodos interpolados: 929
# Nodos interpolados: 930
# Nodos interpolados: 931
# Nodos interpolados: 932
# Nodos interpolados: 933
# Nodos interpolados: 934
# Nodos interpolados: 935
# Nodos interpolados: 936
# Nodos interpolados: 937
# Nodos interpolados: 938
# Nodos interpolados: 939
# Nodos interpolados: 940
# Nodos interpolados: 941
# Nodos interpolados: 942
# Nodos interpolados: 943
# Nodos interpolados: 944
# Nodos interpolados: 945
# Nodos interpolados: 946
# Nodos interpolados: 947
# Nodos interpolados: 948
# Nodos interpolados: 949
# Nodos interpolados: 950
# Nodos interpolados: 951
# Nodos interpolados: 952
# Nodos interpolados: 953
# Nodos interpolados: 954
# Nodos interpolados: 955
# Nodos interpolados: 956
# Nodos interpolados: 957
# Nodos interpolados: 958
# Nodos interpolados: 959
# Nodos interpolados: 960
# Nodos interpolados: 961
# Nodos interpolados: 962
# Nodos interpolados: 963
# Nodos interpolados: 964
# Nodos interpolados: 965
# Nodos interpolados: 966
# Nodos interpolados: 967
# Nodos interpolados: 968
# Nodos interpolados: 969
# Nodos interpolados: 970
# Nodos interpolados: 971
# Nodos interpolados: 972
# Nodos interpolados: 973
# Nodos interpolados: 974
# Nodos interpolados: 975
# Nodos interpolados: 976
# Nodos interpolados: 977
# Nodos interpolados: 978
# Nodos interpolados: 979
# Nodos interpolados: 980
# Nodos interpolados: 981
# Nodos interpolados: 982
# Nodos interpolados: 983
# Nodos interpolados: 984
# Nodos interpolados: 985
# Nodos interpolados: 986
# Nodos interpolados: 987
# Nodos interpolados: 988
# Nodos interpolados: 989
# Nodos interpolados: 990
# Nodos interpolados: 991
# Nodos interpolados: 992
# Nodos interpolados: 993
# Nodos interpolados: 994
# Nodos interpolados: 995
# Nodos interpolados: 996
# Nodos interpolados: 997
# Nodos interpolados: 998
# Nodos interpolados: 999
# Nodos interpolados: 1000
# Nodos interpolados: 1001
# Nodos interpolados: 1002
# Nodos interpolados: 1003
# Nodos interpolados: 1004
# Nodos interpolados: 1005
# Nodos interpolados: 1006
# Nodos interpolados: 1007
# Nodos interpolados: 1008
# Nodos interpolados: 1009
# Nodos interpolados: 1010
# Nodos interpolados: 1011
# Nodos interpolados: 1012
# Nodos interpolados: 1013
# Nodos interpolados: 1014
# Nodos interpolados: 1015
# Nodos interpolados: 1016
# Nodos interpolados: 1017
# Nodos interpolados: 1018
# Nodos interpolados: 1019
# Nodos interpolados: 1020
# Nodos interpolados: 1021
# Nodos interpolados: 1022
# Nodos interpolados: 1023
# Nodos interpolados: 1024
# Nodos interpolados: 1025
# Nodos interpolados: 1026
# Nodos interpolados: 1027
# Nodos interpolados: 1028
# Nodos interpolados: 1029
# Nodos interpolados: 1030
# Nodos interpolados: 1031
# Nodos interpolados: 1032
# Nodos interpolados: 1033
# Nodos interpolados: 1034
# Nodos interpolados: 1035
# Nodos interpolados: 1036
# Nodos interpolados: 1037
# Nodos interpolados: 1038
# Nodos interpolados: 1039
# Nodos interpolados: 1040
# Nodos interpolados: 1041
# Nodos interpolados: 1042
# Nodos interpolados: 1043
# Nodos interpolados: 1044
# Nodos interpolados: 1045
# Nodos interpolados: 1046
# Nodos interpolados: 1047
# Nodos interpolados: 1048
# Nodos interpolados: 1049
# Nodos interpolados: 1050
# Nodos interpolados: 1051
# Nodos interpolados: 1052
# Nodos interpolados: 1053
# Nodos interpolados: 1054
# Nodos interpolados: 1055
# Nodos interpolados: 1056
# Nodos interpolados: 1057
# Nodos interpolados: 1058
# Nodos interpolados: 1059
# Nodos interpolados: 1060
# Nodos interpolados: 1061
# Nodos interpolados: 1062
# Nodos interpolados: 1063
# Nodos interpolados: 1064
# Nodos interpolados: 1065
# Nodos interpolados: 1066
# Nodos interpolados: 1067
# Nodos interpolados: 1068
# Nodos interpolados: 1069
# Nodos interpolados: 1070
# Nodos interpolados: 1071
# Nodos interpolados: 1072
# Nodos interpolados: 1073
# Nodos interpolados: 1074
# Nodos interpolados: 1075
# Nodos interpolados: 1076
# Nodos interpolados: 1077
# Nodos interpolados: 1078
# Nodos interpolados: 1079
# Nodos interpolados: 1080
# Nodos interpolados: 1081
# Nodos interpolados: 1082
# Nodos interpolados: 1083
# Nodos interpolados: 1084
# Nodos interpolados: 1085
# Nodos interpolados: 1086
# Nodos interpolados: 1087
# Nodos interpolados: 1088
# Nodos interpolados: 1089
# Nodos interpolados: 1090
# Nodos interpolados: 1091
# Nodos interpolados: 1092
# Nodos interpolados: 1093
# Nodos interpolados: 1094
# Nodos interpolados: 1095
# Nodos interpolados: 1096
# Nodos interpolados: 1097
# Nodos interpolados: 1098
# Nodos interpolados: 1099
# Nodos interpolados: 1100
# Nodos interpolados: 1101
# Nodos interpolados: 1102
# Nodos interpolados: 1103
# Nodos interpolados: 1104
# Nodos interpolados: 1105
# Nodos interpolados: 1106
# Nodos interpolados: 1107
# Nodos interpolados: 1108
# Nodos interpolados: 1109
# Nodos interpolados: 1110
# Nodos interpolados: 1111
# Nodos interpolados: 1112
# Nodos interpolados: 1113
# Nodos interpolados: 1114
# Nodos interpolados: 1115
# Nodos interpolados: 1116
# Nodos interpolados: 1117
# Nodos interpolados: 1118
# Nodos interpolados: 1119
# Nodos interpolados: 1120
# Nodos interpolados: 1121
# Nodos interpolados: 1122
# Nodos interpolados: 1123
# Nodos interpolados: 1124
# Nodos interpolados: 1125
# Nodos interpolados: 1126
# Nodos interpolados: 1127
# Nodos interpolados: 1128
# Nodos interpolados: 1129
# Nodos interpolados: 1130
# Nodos interpolados: 1131
# Nodos interpolados: 1132
# Nodos interpolados: 1133
# Nodos interpolados: 1134
# Nodos interpolados: 1135
# Nodos interpolados: 1136
# Nodos interpolados: 1137
# Nodos interpolados: 1138
# Nodos interpolados: 1139
# Nodos interpolados: 1140
# Nodos interpolados: 1141
# Nodos interpolados: 1142
# Nodos interpolados: 1143
# Nodos interpolados: 1144
# Nodos interpolados: 1145
# Nodos interpolados: 1146
# Nodos interpolados: 1147
# Nodos interpolados: 1148
# Nodos interpolados: 1149
# Nodos interpolados: 1150
# Nodos interpolados: 1151
# Nodos interpolados: 1152
# Nodos interpolados: 1153
# Nodos interpolados: 1154
# Nodos interpolados: 1155
# Nodos interpolados: 1156
# Nodos interpolados: 1157
# Nodos interpolados: 1158
# Nodos interpolados: 1159
# Nodos interpolados: 1160
# Nodos interpolados: 1161
# Nodos interpolados: 1162
# Nodos interpolados: 1163
# Nodos interpolados: 1164
# Nodos interpolados: 1165
# Nodos interpolados: 1166
# Nodos interpolados: 1167
# Nodos interpolados: 1168
# Nodos interpolados: 1169
# Nodos interpolados: 1170
# Nodos interpolados: 1171
# Nodos interpolados: 1172
# Nodos interpolados: 1173
# Nodos interpolados: 1174
# Nodos interpolados: 1175
# Nodos interpolados: 1176
# Nodos interpolados: 1177
# Nodos interpolados: 1178
# Nodos interpolados: 1179
# Nodos interpolados: 1180
# Nodos interpolados: 1181
# Nodos interpolados: 1182
# Nodos interpolados: 1183
# Nodos interpolados: 1184
# Nodos interpolados: 1185
# Nodos interpolados: 1186
# Nodos interpolados: 1187
# Nodos interpolados: 1188
# Nodos interpolados: 1189
# Nodos interpolados: 1190
# Nodos interpolados: 1191
# Nodos interpolados: 1192
# Nodos interpolados: 1193
# Nodos interpolados: 1194
# Nodos interpolados: 1195
# Nodos interpolados: 1196
# Nodos interpolados: 1197
# Nodos interpolados: 1198
# Nodos interpolados: 1199
# Nodos interpolados: 1200
# Nodos interpolados: 1201
# Nodos interpolados: 1202
# Nodos interpolados: 1203
# Nodos interpolados: 1204
# Nodos interpolados: 1205
# Nodos interpolados: 1206
# Nodos interpolados: 1207
# Nodos interpolados: 1208
# Nodos interpolados: 1209
# Nodos interpolados: 1210
# Nodos interpolados: 1211
# Nodos interpolados: 1212
# Nodos interpolados: 1213
# Nodos interpolados: 1214
# Nodos interpolados: 1215
# Nodos interpolados: 1216
# Nodos interpolados: 1217
# Nodos interpolados: 1218
# Nodos interpolados: 1219
# Nodos interpolados: 1220
# Nodos interpolados: 1221
# Nodos interpolados: 1222
# Nodos interpolados: 1223
# Nodos interpolados: 1224
# Nodos interpolados: 1225
# Nodos interpolados: 1226
# Nodos interpolados: 1227
# Nodos interpolados: 1228
# Nodos interpolados: 1229
# Nodos interpolados: 1230
# Nodos interpolados: 1231
# Nodos interpolados: 1232
# Nodos interpolados: 1233
# Nodos interpolados: 1234
# Nodos interpolados: 1235
# Nodos interpolados: 1236
# Nodos interpolados: 1237
# Nodos interpolados: 1238
# Nodos interpolados: 1239
# Nodos interpolados: 1240
# Nodos interpolados: 1241
# Nodos interpolados: 1242
# Nodos interpolados: 1243
# Nodos interpolados: 1244
# Nodos interpolados: 1245
# Nodos interpolados: 1246
# Nodos interpolados: 1247
# Nodos interpolados: 1248
# Nodos interpolados: 1249
# Nodos interpolados: 1250
# Nodos interpolados: 1251
# Nodos interpolados: 1252
# Nodos interpolados: 1253
# Nodos interpolados: 1254
# Nodos interpolados: 1255
# Nodos interpolados: 1256
# Nodos interpolados: 1257
# Nodos interpolados: 1258
# Nodos interpolados: 1259
# Nodos interpolados: 1260
# Nodos interpolados: 1261
# Nodos interpolados: 1262
# Nodos interpolados: 1263
# Nodos interpolados: 1264
# Nodos interpolados: 1265
# Nodos interpolados: 1266
# Nodos interpolados: 1267
# Nodos interpolados: 1268
# Nodos interpolados: 1269
# Nodos interpolados: 1270
# Nodos interpolados: 1271
# Nodos interpolados: 1272
# Nodos interpolados: 1273
# Nodos interpolados: 1274
# Nodos interpolados: 1275
# Nodos interpolados: 1276
# Nodos interpolados: 1277
# Nodos interpolados: 1278
# Nodos interpolados: 1279
# Nodos interpolados: 1280
# Nodos interpolados: 1281
# Nodos interpolados: 1282
# Nodos interpolados: 1283
# Nodos interpolados: 1284
# Nodos interpolados: 1285
# Nodos interpolados: 1286
# Nodos interpolados: 1287
# Nodos interpolados: 1288
# Nodos interpolados: 1289
# Nodos interpolados: 1290
# Nodos interpolados: 1291
# Nodos interpolados: 1292
# Nodos interpolados: 1293
# Nodos interpolados: 1294
# Nodos interpolados: 1295
# Nodos interpolados: 1296
# Nodos interpolados: 1297
# Nodos interpolados: 1298
# Nodos interpolados: 1299
# Nodos interpolados: 1300
# Nodos interpolados: 1301
# Nodos interpolados: 1302
# Nodos interpolados: 1303
# Nodos interpolados: 1304
# Nodos interpolados: 1305
# Nodos interpolados: 1306
# Nodos interpolados: 1307
# Nodos interpolados: 1308
# Nodos interpolados: 1309
# Nodos interpolados: 1310
# Nodos interpolados: 1311
# Nodos interpolados: 1312
# Nodos interpolados: 1313
# Nodos interpolados: 1314
# Nodos interpolados: 1315
# Nodos interpolados: 1316
# Nodos interpolados: 1317
# Nodos interpolados: 1318
# Nodos interpolados: 1319
# Nodos interpolados: 1320
# Nodos interpolados: 1321
# Nodos interpolados: 1322
# Nodos interpolados: 1323
# Nodos interpolados: 1324
# Nodos interpolados: 1325
# Nodos interpolados: 1326
# Nodos interpolados: 1327
# Nodos interpolados: 1328
# Nodos interpolados: 1329
# Nodos interpolados: 1330
# Nodos interpolados: 1331
# Nodos interpolados: 1332
# Nodos interpolados: 1333
# Nodos interpolados: 1334
# Nodos interpolados: 1335
# Nodos interpolados: 1336
# Nodos interpolados: 1337
# Nodos interpolados: 1338
# Nodos interpolados: 1339
# Nodos interpolados: 1340
# Nodos interpolados: 1341
# Nodos interpolados: 1342
# Nodos interpolados: 1343
# Nodos interpolados: 1344
# Nodos interpolados: 1345
# Nodos interpolados: 1346
# Nodos interpolados: 1347
# Nodos interpolados: 1348
# Nodos interpolados: 1349
# Nodos interpolados: 1350
# Nodos interpolados: 1351
# Nodos interpolados: 1352
# Nodos interpolados: 1353
# Nodos interpolados: 1354
# Nodos interpolados: 1355
# Nodos interpolados: 1356
# Nodos interpolados: 1357
# Nodos interpolados: 1358
# Nodos interpolados: 1359
# Nodos interpolados: 1360
# Nodos interpolados: 1361
# Nodos interpolados: 1362
# Nodos interpolados: 1363
# Nodos interpolados: 1364
# Nodos interpolados: 1365
# Nodos interpolados: 1366
# Nodos interpolados: 1367
# Nodos interpolados: 1368
# Nodos interpolados: 1369
# Nodos interpolados: 1370
# Nodos interpolados: 1371
# Nodos interpolados: 1372
# Nodos interpolados: 1373
# Nodos interpolados: 1374
# Nodos interpolados: 1375
# Nodos interpolados: 1376
# Nodos interpolados: 1377
# Nodos interpolados: 1378
# Nodos interpolados: 1379
# Nodos interpolados: 1380
# Nodos interpolados: 1381
# Nodos interpolados: 1382
# Nodos interpolados: 1383
# Nodos interpolados: 1384
# Nodos interpolados: 1385
# Nodos interpolados: 1386
# Nodos interpolados: 1387
# Nodos interpolados: 1388
# Nodos interpolados: 1389
# Nodos interpolados: 1390
# Nodos interpolados: 1391
# Nodos interpolados: 1392
# Nodos interpolados: 1393
# Nodos interpolados: 1394
# Nodos interpolados: 1395
# Nodos interpolados: 1396
# Nodos interpolados: 1397
# Nodos interpolados: 1398
# Nodos interpolados: 1399
# Nodos interpolados: 1400
# Nodos interpolados: 1401
# Nodos interpolados: 1402
# Nodos interpolados: 1403
# Nodos interpolados: 1404
# Nodos interpolados: 1405
# Nodos interpolados: 1406
# Nodos interpolados: 1407
# Nodos interpolados: 1408
# Nodos interpolados: 1409
# Nodos interpolados: 1410
# Nodos interpolados: 1411
# Nodos interpolados: 1412
# Nodos interpolados: 1413
# Nodos interpolados: 1414
# Nodos interpolados: 1415
# Nodos interpolados: 1416
# Nodos interpolados: 1417
# Nodos interpolados: 1418
# Nodos interpolados: 1419
# Nodos interpolados: 1420
# Nodos interpolados: 1421
# Nodos interpolados: 1422
# Nodos interpolados: 1423
# Nodos interpolados: 1424
# Nodos interpolados: 1425
# Nodos interpolados: 1426
# Nodos interpolados: 1427
# Nodos interpolados: 1428
# Nodos interpolados: 1429
# Nodos interpolados: 1430
# Nodos interpolados: 1431
# Nodos interpolados: 1432
# Nodos interpolados: 1433
# Nodos interpolados: 1434
# Nodos interpolados: 1435
# Nodos interpolados: 1436
# Nodos interpolados: 1437
# Nodos interpolados: 1438
# Nodos interpolados: 1439
# Nodos interpolados: 1440
# Nodos interpolados: 1441
# Nodos interpolados: 1442
# Nodos interpolados: 1443
# Nodos interpolados: 1444
# Nodos interpolados: 1445
# Nodos interpolados: 1446
# Nodos interpolados: 1447
# Nodos interpolados: 1448
# Nodos interpolados: 1449
# Nodos interpolados: 1450
# Nodos interpolados: 1451
# Nodos interpolados: 1452
# Nodos interpolados: 1453
# Nodos interpolados: 1454
# Nodos interpolados: 1455
# Nodos interpolados: 1456
# Nodos interpolados: 1457
# Nodos interpolados: 1458
# Nodos interpolados: 1459
# Nodos interpolados: 1460
# Nodos interpolados: 1461
# Nodos interpolados: 1462
# Nodos interpolados: 1463
# Nodos interpolados: 1464
# Nodos interpolados: 1465
# Nodos interpolados: 1466
# Nodos interpolados: 1467
# Nodos interpolados: 1468
# Nodos interpolados: 1469
# Nodos interpolados: 1470
# Nodos interpolados: 1471
# Nodos interpolados: 1472
# Nodos interpolados: 1473
# Nodos interpolados: 1474
# Nodos interpolados: 1475
# Nodos interpolados: 1476
# Nodos interpolados: 1477
# Nodos interpolados: 1478
# Nodos interpolados: 1479
# Nodos interpolados: 1480
# Nodos interpolados: 1481
# Nodos interpolados: 1482
# Nodos interpolados: 1483
# Nodos interpolados: 1484
# Nodos interpolados: 1485
# Nodos interpolados: 1486
# Nodos interpolados: 1487
# Nodos interpolados: 1488
# Nodos interpolados: 1489
# Nodos interpolados: 1490
# Nodos interpolados: 1491
# Nodos interpolados: 1492
# Nodos interpolados: 1493
# Nodos interpolados: 1494
# Nodos interpolados: 1495
# Nodos interpolados: 1496
# Nodos interpolados: 1497
# Nodos interpolados: 1498
# Nodos interpolados: 1499
# Nodos interpolados: 1500
# Nodos interpolados: 1501
# Nodos interpolados: 1502
# Nodos interpolados: 1503
# Nodos interpolados: 1504
# Nodos interpolados: 1505
# Nodos interpolados: 1506
# Nodos interpolados: 1507
# Nodos interpolados: 1508
# Nodos interpolados: 1509
# Nodos interpolados: 1510
# Nodos interpolados: 1511
# Nodos interpolados: 1512
# Nodos interpolados: 1513
# Nodos interpolados: 1514
# Nodos interpolados: 1515
# Nodos interpolados: 1516
# Nodos interpolados: 1517
# Nodos interpolados: 1518
# Nodos interpolados: 1519
# Nodos interpolados: 1520
# Nodos interpolados: 1521
# Nodos interpolados: 1522
# Nodos interpolados: 1523
# Nodos interpolados: 1524
# Nodos interpolados: 1525
# Nodos interpolados: 1526
# Nodos interpolados: 1527
# Nodos interpolados: 1528
# Nodos interpolados: 1529
# Nodos interpolados: 1530
# Nodos interpolados: 1531
# Nodos interpolados: 1532
# Nodos interpolados: 1533
# Nodos interpolados: 1534
# Nodos interpolados: 1535
# Nodos interpolados: 1536
# Nodos interpolados: 1537
# Nodos interpolados: 1538
# Nodos interpolados: 1539
# Nodos interpolados: 1540
# Nodos interpolados: 1541
# Nodos interpolados: 1542
# Nodos interpolados: 1543
# Nodos interpolados: 1544
# Nodos interpolados: 1545
# Nodos interpolados: 1546
# Nodos interpolados: 1547
# Nodos interpolados: 1548
# Nodos interpolados: 1549
# Nodos interpolados: 1550
# Nodos interpolados: 1551
# Nodos interpolados: 1552
# Nodos interpolados: 1553
# Nodos interpolados: 1554
# Nodos interpolados: 1555
# Nodos interpolados: 1556
# Nodos interpolados: 1557
# Nodos interpolados: 1558
# Nodos interpolados: 1559
# Nodos interpolados: 1560
# Nodos interpolados: 1561
# Nodos interpolados: 1562
# Nodos interpolados: 1563
# Nodos interpolados: 1564
# Nodos interpolados: 1565
# Nodos interpolados: 1566
# Nodos interpolados: 1567
# Nodos interpolados: 1568
# Nodos interpolados: 1569
# Nodos interpolados: 1570
# Nodos interpolados: 1571
# Nodos interpolados: 1572
# Nodos interpolados: 1573
# Nodos interpolados: 1574
# Nodos interpolados: 1575
# Nodos interpolados: 1576
# Nodos interpolados: 1577
# Nodos interpolados: 1578
# Nodos interpolados: 1579
# Nodos interpolados: 1580
# Nodos interpolados: 1581
# Nodos interpolados: 1582
# Nodos interpolados: 1583
# Nodos interpolados: 1584
# Nodos interpolados: 1585
# Nodos interpolados: 1586
# Nodos interpolados: 1587
# Nodos interpolados: 1588
# Nodos interpolados: 1589
# Nodos interpolados: 1590
# Nodos interpolados: 1591
# Nodos interpolados: 1592
# Nodos interpolados: 1593
# Nodos interpolados: 1594
# Nodos interpolados: 1595
# Nodos interpolados: 1596
# Nodos interpolados: 1597
# Nodos interpolados: 1598
# Nodos interpolados: 1599
# Nodos interpolados: 1600
# Nodos interpolados: 1601
# Nodos interpolados: 1602
# Nodos interpolados: 1603
# Nodos interpolados: 1604
# Nodos interpolados: 1605
# Nodos interpolados: 1606
# Nodos interpolados: 1607
# Nodos interpolados: 1608
# Nodos interpolados: 1609
# Nodos interpolados: 1610
# Nodos interpolados: 1611
# Nodos interpolados: 1612
# Nodos interpolados: 1613
# Nodos interpolados: 1614
# Nodos interpolados: 1615
# Nodos interpolados: 1616
# Nodos interpolados: 1617
# Nodos interpolados: 1618
# Nodos interpolados: 1619
# Nodos interpolados: 1620
# Nodos interpolados: 1621
# Nodos interpolados: 1622
# Nodos interpolados: 1623
# Nodos interpolados: 1624
# Nodos interpolados: 1625
# Nodos interpolados: 1626
# Nodos interpolados: 1627
# Nodos interpolados: 1628
# Nodos interpolados: 1629
# Nodos interpolados: 1630
# Nodos interpolados: 1631
# Nodos interpolados: 1632
# Nodos interpolados: 1633
# Nodos interpolados: 1634
# Nodos interpolados: 1635
# Nodos interpolados: 1636
# Nodos interpolados: 1637
# Nodos interpolados: 1638
# Nodos interpolados: 1639
# Nodos interpolados: 1640
# Nodos interpolados: 1641
# Nodos interpolados: 1642
# Nodos interpolados: 1643
# Nodos interpolados: 1644
# Nodos interpolados: 1645
# Nodos interpolados: 1646
# Nodos interpolados: 1647
# Nodos interpolados: 1648
# Nodos interpolados: 1649
# Nodos interpolados: 1650
# Nodos interpolados: 1651
# Nodos interpolados: 1652
# Nodos interpolados: 1653
# Nodos interpolados: 1654
# Nodos interpolados: 1655
# Nodos interpolados: 1656
# Nodos interpolados: 1657
# Nodos interpolados: 1658
# Nodos interpolados: 1659
# Nodos interpolados: 1660
# Nodos interpolados: 1661
# Nodos interpolados: 1662
# Nodos interpolados: 1663
# Nodos interpolados: 1664
# Nodos interpolados: 1665
# Nodos interpolados: 1666
# Nodos interpolados: 1667
# Nodos interpolados: 1668
# Nodos interpolados: 1669
# Nodos interpolados: 1670
# Nodos interpolados: 1671
# Nodos interpolados: 1672
# Nodos interpolados: 1673
# Nodos interpolados: 1674
# Nodos interpolados: 1675
# Nodos interpolados: 1676
# Nodos interpolados: 1677
# Nodos interpolados: 1678
# Nodos interpolados: 1679
# Nodos interpolados: 1680
# Nodos interpolados: 1681
# Nodos interpolados: 1682
# Nodos interpolados: 1683
# Nodos interpolados: 1684
# Nodos interpolados: 1685
# Nodos interpolados: 1686
# Nodos interpolados: 1687
# Nodos interpolados: 1688
# Nodos interpolados: 1689
# Nodos interpolados: 1690
# Nodos interpolados: 1691
# Nodos interpolados: 1692
# Nodos interpolados: 1693
# Nodos interpolados: 1694
# Nodos interpolados: 1695
# Nodos interpolados: 1696
# Nodos interpolados: 1697
# Nodos interpolados: 1698
# Nodos interpolados: 1699
# Nodos interpolados: 1700
# Nodos interpolados: 1701
# Nodos interpolados: 1702
# Nodos interpolados: 1703
# Nodos interpolados: 1704
# Nodos interpolados: 1705
# Nodos interpolados: 1706
# Nodos interpolados: 1707
# Nodos interpolados: 1708
# Nodos interpolados: 1709
# Nodos interpolados: 1710
# Nodos interpolados: 1711
# Nodos interpolados: 1712
# Nodos interpolados: 1713
# Nodos interpolados: 1714
# Nodos interpolados: 1715
# Nodos interpolados: 1716
# Nodos interpolados: 1717
# Nodos interpolados: 1718
# Nodos interpolados: 1719
# Nodos interpolados: 1720
# Nodos interpolados: 1721
# Nodos interpolados: 1722
# Nodos interpolados: 1723
# Nodos interpolados: 1724
# Nodos interpolados: 1725
# Nodos interpolados: 1726
# Nodos interpolados: 1727
# Nodos interpolados: 1728
# Nodos interpolados: 1729
# Nodos interpolados: 1730
# Nodos interpolados: 1731
# Nodos interpolados: 1732
# Nodos interpolados: 1733
# Nodos interpolados: 1734
# Nodos interpolados: 1735
# Nodos interpolados: 1736
# Nodos interpolados: 1737
# Nodos interpolados: 1738
# Nodos interpolados: 1739
# Nodos interpolados: 1740
# Nodos interpolados: 1741
# Nodos interpolados: 1742
# Nodos interpolados: 1743
# Nodos interpolados: 1744
# Nodos interpolados: 1745
# Nodos interpolados: 1746
# Nodos interpolados: 1747
# Nodos interpolados: 1748
# Nodos interpolados: 1749
# Nodos interpolados: 1750
# Nodos interpolados: 1751
# Nodos interpolados: 1752
# Nodos interpolados: 1753
# Nodos interpolados: 1754
# Nodos interpolados: 1755
# Nodos interpolados: 1756
# Nodos interpolados: 1757
# Nodos interpolados: 1758
# Nodos interpolados: 1759
# Nodos interpolados: 1760
# Nodos interpolados: 1761
# Nodos interpolados: 1762
# Nodos interpolados: 1763
# Nodos interpolados: 1764
# Nodos interpolados: 1765
# Nodos interpolados: 1766
# Nodos interpolados: 1767
# Nodos interpolados: 1768
# Nodos interpolados: 1769
# Nodos interpolados: 1770
# Nodos interpolados: 1771
# Nodos interpolados: 1772
# Nodos interpolados: 1773
# Nodos interpolados: 1774
# Nodos interpolados: 1775
# Nodos interpolados: 1776
# Nodos interpolados: 1777
# Nodos interpolados: 1778
# Nodos interpolados: 1779
# Nodos interpolados: 1780
# Nodos interpolados: 1781
# Nodos interpolados: 1782
# Nodos interpolados: 1783
# Nodos interpolados: 1784
# Nodos interpolados: 1785
# Nodos interpolados: 1786
# Nodos interpolados: 1787
# Nodos interpolados: 1788
# Nodos interpolados: 1789
# Nodos interpolados: 1790
# Nodos interpolados: 1791
# Nodos interpolados: 1792
# Nodos interpolados: 1793
# Nodos interpolados: 1794
# Nodos interpolados: 1795
# Nodos interpolados: 1796
# Nodos interpolados: 1797
# Mapa guardado como mapa_grafo_contenedores.html
